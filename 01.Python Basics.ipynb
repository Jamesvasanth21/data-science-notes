# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1nx7EDYFZvWRHaV2aXjabisSK58QtSm0o#scrollTo=kVEavBR6gdiA)

# %% [markdown]
# ###  Basic components of Python Programming

# %% [markdown]
# #### Identifier
# ##### Identifiers are the names used to identify variables, functions, classes, modules, etc.

# %%
name = "Alice"
_age = 30
total1 = 100.00

# %%
print(name, _age)
print(_age)
print(total1)
# Out:
# Alice 30
# 30
# 100.0

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# #### Print the type of the Identifier

# %%
print(type(name))
print(type(_age))
print(type(total1))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# #### Simple Keywords

# %%
# False, True, None, if, else, elif, while, for, break, continue,
# class, def, return, import, from, try, except, raise, with, as, lambda, pass

# %%
import keyword
print(keyword.kwlist)

# %% [markdown]
# #### Indentation

# %%
age = 19

# %%
if age > 18:
  print("Adult")     # Indented block
  print("Welcome")
  print("Adult. His age is",age)

else:
  print("Minor. His age is",age)
print("Completed")
# Out:
# Adult
# Welcome
# Adult. His age is 19

# %%
age = 60
if age > 18 and age < 60:
  print("Adult. His age is",age)
elif age >= 60:
  print("Senior. His age is",age)
else:
  print("Minor. His age is",age)
# Out:
# Senior. His age is 60

# %%
age = 59
height= 5.0

# Filter by maximum
if age >= 60:
  print("Senior. His age is",age)
  print("Please advise to Walk")
  if height >= 6.0:
    print("Tall. His height is",height)
  elif height >= 5.0:
    print("Medium. His height is",height)
  else:
    print("Short. His height is",height)

elif age >= 18:
  print("Adult. His age is",age)
  print("Please advise to Exercise")
  if height >= 6.0:
    print("Tall. His height is",height)
  elif height >= 5.0:
    print("Medium. His height is",height)
  else:
    print("Short. His height is",height)
  print("Completed Printin for Adult")
else:
  print("Minor. His age is",age)
  print("Please advise to Play")
  if height >= 6.0:
    print("Tall. His height is",height)
  elif height >= 5.0:
    print("Medium. His height is",height)
  else:
    print("Short. His height is",height)
# Out:
# Adult. His age is 59
# Please advise to Exercise
# Medium. His height is 5.0
# Completed Printin for Adult

# %%
if _age > 18:
    print("Adult")     # Indented block
    print("Welcome")
else:
    print("Minor")

# %% [markdown]
# #### Incorrect Indentation:

# %%
if _age > 18:
print("Adult")  # Error: expected an indented block
# Out:
#   File "<ipython-input-36-4a03c907567d>", line 2
#     print("Adult")  # Error: expected an indented block
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# #### Single Comments

# %%
print(age)
# Out:
# 59

# %%
# print(age)

# %% [markdown]
# #### Multiple Comments

# %%
# name = "Alice"
# _age = 30
# total1 = 100

# %% [markdown]
# #### Getting Input from User

# %%
name = input("Enter your name: ")
print("Hello,", name)
# Out:
# chash
# Hello, chash

# %% [markdown]
# Getting Input from User and Casting

# %%
age = int(input("Enter your age: "))
print(type(age))
# Out:
# Enter your age: 89
# <class 'int'>

# %% [markdown]
# #### Simple Function and Docstring Example

# %%
def add(a, b):
    """Input: a, b Return the sum of a and b"""
    return a + b

# %%
print(add.__doc__)
# Out:
# Input: a, b Return the sum of a and b

# %% [markdown]
# ### Data Types and Type Conversion
#
# - Every value in a program has a specific type.
#
# - Integer (int): represents positive or negative whole numbers.
#
# - Floating point number (float): represents real numbers like 3.14159.
#
# - Character string (usually called “string”, str): text.
# Written in either single quotes or double quotes (as long as they match).
#
#     - The quote marks aren’t printed when the string is displayed.

# %%
print(type(5), type(5.2), type("5"))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
a = "5"
b = int(a)
print(a, type(a))
print(b, type(b))
# Out:
# 5 <class 'str'>
# 5 <class 'int'>
# 5555555555

# %%
print(a * 10)
# Out:
# 5555555555

# %%
print(b * 10)
# Out:
# 50

# %%
print("This is a string.")
# Out:
# This is a string.

# %%
print(5+2,'\n', 5-2,'\t', 5*2,'\t', 5/2,'\t', 5//2,'\t', 5**2)
print("Hello")
# Out:
# 7
#  3 	 10 	 2.5 	 2 	 25
# Hello

# %% [markdown]
# ### Lists in Python
# - Lists are one of the most powerful tools in python.
# - They are just like the arrays declared in other languages.
# - The most powerful thing is that list need not be always homogeneous.
# -  Lists are mutable, i.e., they can be altered once declared.

# %%
alist = [1, "a" , 2 , 5.3]
print(alist)
# Out:
# [1, 'a', 2, 5.3]

# %%
print(alist[0],'\t', alist[1], '\t', alist[1:4], '\t', len(alist))
# Out:
# 1 	 a 	 ['a', 2, 5.3] 	 4

# %%
blist = []
print(blist)
blist.append(4)
print(blist)
blist.append(10)
print(blist)
# Out:
# []
# [4]
# [4, 10]

# %%
blist.pop()
# Out:
# 10

# %%
print(blist)
# Out:
# [4]

# %%
alist = [1, "a" , 8 , 5.3]
print(alist[100])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3-4117645016.py in <cell line: 0>()
#       1 alist = [1, "a" , 8 , 5.3]
# ----> 2 print(alist[100])
#
# IndexError: list index out of range

# %% [markdown]
# #### List Assignment

# %%
alist[0] = 0
print(alist)
# Out:
# [0, 'a', 8, 5.3]

# %% [markdown]
# #### List Insertion
# list.insert(index, element)

# %%
fruits = ['apple', 'banana', 'cherry']
fruits.insert(1, 'orange')

print(fruits)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
fruits = ['apple', 'banana', 'cherry']
fruits[1] = 'orange'

print(fruits)
# Out:
# ['apple', 'orange', 'cherry']

# %% [markdown]
# #### Self-Refrential Structure
# ```python
# alist = [1, "a", 8, 5.3]
# alist.append(alist)
# print(alist[4])
# ```
#
# ##### Step-by-step explanation:
#
# 1. Initial list:
#
#    ```python
#    alist = [1, "a", 8, 5.3]
#    ```
#
# 2. After `alist.append(alist)`:
#
#    * You're appending the **list itself** as the last element of the list.
#    * So now `alist` becomes:
#
#      ```python
#      [1, "a", 8, 5.3, [...]]
#      ```
#    * More precisely:
#
#      ```python
#      alist = [1, "a", 8, 5.3, alist]
#      ```
#
#    This creates a **self-referential structure** — the last element is a reference to the entire list.
#
# 3. `print(alist[4])`:
#
#    * `alist[4]` **is the list itself** (i.e., `alist`)
#    * So the output will be:
#
#      ```python
#      [1, 'a', 8, 5.3, [...]]
#      ```
#    * In most Python interpreters, this prints something like:
#
#      ```
#      [1, 'a', 8, 5.3, [...]]
#      ```
#
#    This `[...]` notation is used to indicate **self-reference** — Python avoids infinite recursion in the printout.
#
# ---
#
# ##### ✅ Final Answer:
#
# ```
# [1, 'a', 8, 5.3, [...]]
# ```

# %% [markdown]
# ### Tuples in Python
# - Tuples are just like lists with the exception that tuples cannot be changed once declared.

# %%
alist = [1, "a" , 2 , 5.3]
print(alist, type(alist))
# Out:
# [1, 'a', 2, 5.3] <class 'list'>

# %%
alist[1] = "b"

# %%
alist
# Out:
# [1, 'b', 2, 5.3]

# %%
t = (1, "a", "string", 1+2)
print(t, '\t',type(t))
print(t[1])
# Out:
# (1, 'a', 'string', 3) 	 <class 'tuple'>
# a

# %%
t[1] = "b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-492746acdde0> in <cell line: 0>()
# ----> 1 t[1] = "b"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Dictionaries in Python
# - Dictionary holds key:value pairs.
# - Indexing of Python Dictionary is done with the help of keys.

# %%
d = {}
d["fall2021"] = 50
d["spring2022"] = 80
print(d)
# Out:
# {'fall2021': 50, 'spring2022': 80}

# %%
print(d.keys())
# Out:
# dict_keys(['fall2021', 'spring2022'])

# %%
print(d.items())
# Out:
# dict_items([('fall2021', 50), ('spring2022', 80)])

# %% [markdown]
# ### Sets in Python
# - Set does not allow any duplicate element.

# %%
my_set = set([1, 2, 2, 4, 4, 6, 7])
print(my_set)
# Out:
# {1, 2, 4, 6, 7}

# %%
type(my_set)
# Out:
# set

# %%
# Creating sets
set1 = {1, 2, 3}
set2 = set([3, 4, 5, 6, 6, 6])
print(set2)

# Empty set
empty_set = set()
# Out:
# {3, 4, 5, 6}

# %%
set1 = {1, 2, 4, 6, 7, 7}
print(set1)
# Out:
# {1, 2, 4, 6, 7}

# %%
empty_set.add(10)
empty_set
# Out:
# {10}

# %%
empty_set.add(10)
empty_set
# Out:
# {10}

# %% [markdown]
# ### Iterate over a list in Python
# - Method 1: Using For loop
# - Method 2: For loop and range()
# - Method 3: Using while loop
# - Method 4: Using list comprehension
# - Method 5: Using enumerate()

# %%
alist = [1, 3, 5, 7, 9]

# %%
for item in alist:
    print(item)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for index in range(0, len(alist), 2):
    print(index,alist[index])
# Out:
# 0 1
# 2 5
# 4 9

# %%
alist[range(len(alist))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-9650f5a02b9f> in <cell line: 0>()
# ----> 1 alist[range(len(alist))]
#
# TypeError: list indices must be integers or slices, not range

# %%
alist[2:len(alist)]
# Out:
# [5, 7, 9]

# %%
alist =  [1, 3, 5, 7, 9]

# %%
i = 0
while i < len(alist):
    print(alist[i])
    i += 2
# Out:
# 1
# 5
# 9

# %%
for i, val in enumerate(alist):
    print ("index", i, ", value:",val)
# Out:
# index 0 , value: 1
# index 1 , value: 3
# index 2 , value: 5
# index 3 , value: 7
# index 4 , value: 9

# %% [markdown]
# ### if statement

# %%
x = 5

if x < 0:
    print('Negative')
elif x == 0:
    print('Zero')
else:
    print('Positive')
# Out:
# Positive

# %% [markdown]
# ### Defining Functions

# %%
def square(num):
    num_new = num ** 2
    return num_new

# %%
square(4)
# Out:
# 16

# %%
import time
start_time = time.time()

for i in range(1000000000):
    square(i)

end_time = time.time()
print("running time %s seconds" % (end_time - start_time))
print(start_time)
print(end_time)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-8-4254165388.py in <cell line: 0>()
#       3
#       4 for i in range(1000000000):
# ----> 5     square(i)
#       6
#       7 end_time = time.time()
#
# /tmp/ipython-input-5-4175773760.py in square(num)
# ----> 1 def square(num):
#       2     num_new = num ** 2
#       3     return num_new
#
# KeyboardInterrupt:

# %%
import time
start_time = time.time()
print(start_time)
# Out:
# 1747884230.3992918

# %%
import time

print(time.ctime()) # Prints a formatted string
print(time.localtime()) # Prints a struct_time object
print(time.strftime("%m-%Y-%d %H:%M:%S", time.localtime())) # Prints a custom formatted string
# Out:
# Fri Jul 11 03:42:17 2025
# time.struct_time(tm_year=2025, tm_mon=7, tm_mday=11, tm_hour=3, tm_min=42, tm_sec=17, tm_wday=4, tm_yday=192, tm_isdst=0)
# 07-2025-11 03:42:17

# %%
# Using an iterator manually
nums = [1, 2, 3]
it = iter(nums)

print(next(it))  # Output: 1
print(next(it))  # Output: 2
print(next(it))  # Output: 3
# print(next(it)) # now raises StopIteration
# Out:
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-58-9e09bf047d32> in <cell line: 0>()
#       6 print(next(it))  # Output: 2
#       7 print(next(it))  # Output: 3
# ----> 8 print(next(it)) # now raises StopIteration
#
# StopIteration:

# %% [markdown]
# ### Defining Classes

# %%
import time
"""
Record multiple running times.
"""
class Timer:
    def __init__(self):
        self.times = []

    def start(self):
        self.tik = time.time()

    def stop(self):
        self.times.append(time.time() - self.tik)
        return self.times[-1]

# %%
timer = Timer()

timer.start()
for i in range(100):
    square(i)

print(timer.stop())

timer.start()
for i in range(10000):
    square(i)

print(timer.stop())

timer.start()
for i in range(1000000):
    square(i)

print(timer.stop())

# %%
timer.times
